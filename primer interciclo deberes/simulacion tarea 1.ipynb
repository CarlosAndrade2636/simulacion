# %% [markdown]
# ### pruebas con 100 interacciones

# %%
import random
uno=0
dos=0
tres=0
cuatro=0
cinco=0
seis=0
siete=0
ocho=0
nueve=0
dies=0
once=0
doce=0

for i in range(100):
   numero1=(random.randint(1, 6))
  # numero1 =(randrange(6))
  # print (numero1)
   numero3=(random.randint(1, 6))
   #numero3 = (randrange(6))
  # numero=(choice(["uno", "dos", "tres", "cuatro","cinco", "seis"]))
   #numero2=(choice(["uno", "dos", "tres", "cuatro","cinco", "seis"]))
   total= numero1 +numero3
   if total == 2:
    dos=dos+1  
   if total == 3:
    tres=tres+1
   if total == 4:
    cuatro=cuatro+1
   if total == 5:
    cinco=cinco+1
   if total == 6:
    seis=seis+1
   if total == 7:
    siete=siete+1
   if total == 8:
    ocho=ocho+1 
   if total == 9:
    nueve=nueve+1
   if total == 10:
    dies=dies+1
   if total == 11:
    once=once+1
   if total == 12:
    doce=doce+1
  
    
print("total de 2")
print("porcentaje: ", round((dos/100)*100,2),"%")
print("total de 3")
print("porcentaje: ", round((tres/100)*100,2),"%")
print("total de 4")
print("porcentaje: ", round((cuatro/100)*100,2),"%")
print("total de 5")
print("porcentaje: ", round((cinco/100)*100,2),"%")
print("total de 6")
print("porcentaje: ", round((seis/100)*100,2),"%")
print("total de 7")
print("porcentaje: ", round((siete/100)*100,2),"%")
print("total de 8")
print("porcentaje: ", round((ocho/100)*100,2),"%")
print("total de 9")
print("porcentaje: ", round((nueve/100)*100,2),"%")
print("total de 10")
print("porcentaje: ", round((dies/100)*100,2),"%")
print("total de 11")
print("porcentaje: ", round((once/100)*100,2),"%")
print("total de 12")
print("porcentaje: ", round((doce/100)*100,2),"%")
# Out:
# total de 2
# porcentaje:  3.0 %
# total de 3
# porcentaje:  5.0 %
# total de 4
# porcentaje:  10.0 %
# total de 5
# porcentaje:  9.0 %
# total de 6
# porcentaje:  9.0 %
# total de 7
# porcentaje:  23.0 %
# total de 8
# porcentaje:  6.0 %
# total de 9
# porcentaje:  17.0 %
# total de 10
# porcentaje:  11.0 %
# total de 11
# porcentaje:  5.0 %
# total de 12
# porcentaje:  2.0 %

# %% [markdown]
# ### con 1000  interacciones

# %%
import random
uno=0
dos=0
tres=0
cuatro=0
cinco=0
seis=0
siete=0
ocho=0
nueve=0
dies=0
once=0
doce=0
for i in range(1000):
   numero1=(random.randint(1, 6))
  # numero1 =(randrange(6))
  # print (numero1)
   numero3=(random.randint(1, 6))
   #numero3 = (randrange(6))
  # numero=(choice(["uno", "dos", "tres", "cuatro","cinco", "seis"]))
   #numero2=(choice(["uno", "dos", "tres", "cuatro","cinco", "seis"]))
   total= numero1 +numero3
   if total == 2:
    dos=dos+1  
   if total == 3:
    tres=tres+1
   if total == 4:
    cuatro=cuatro+1
   if total == 5:
    cinco=cinco+1
   if total == 6:
    seis=seis+1
   if total == 7:
    siete=siete+1
   if total == 8:
    ocho=ocho+1 
   if total == 9:
    nueve=nueve+1
   if total == 10:
    dies=dies+1
   if total == 11:
    once=once+1
   if total == 12:
    doce=doce+1
  
    
print("total de 2")
print("porcentaje: ", round((dos/1000)*100,2),"%")
print("total de 3")
print("porcentaje: ", round((tres/1000)*100,2),"%")
print("total de 4")
print("porcentaje: ", round((cuatro/1000)*100,2),"%")
print("total de 5")
print("porcentaje: ", round((cinco/1000)*100,2),"%")
print("total de 6")
print("porcentaje: ", round((seis/1000)*100,2),"%")
print("total de 7")
print("porcentaje: ", round((siete/1000)*100,2),"%")
print("total de 8")
print("porcentaje: ", round((ocho/1000)*100,2),"%")
print("total de 9")
print("porcentaje: ", round((nueve/1000)*100,2),"%")
print("total de 10")
print("porcentaje: ", round((dies/1000)*100,2),"%")
print("total de 11")
print("porcentaje: ", round((once/1000)*100,2),"%")
print("total de 12")
print("porcentaje: ", round((doce/1000)*100,2),"%")
# Out:
# total de 2
# porcentaje:  3.0 %
# total de 3
# porcentaje:  5.8 %
# total de 4
# porcentaje:  9.1 %
# total de 5
# porcentaje:  8.9 %
# total de 6
# porcentaje:  14.7 %
# total de 7
# porcentaje:  17.5 %
# total de 8
# porcentaje:  13.8 %
# total de 9
# porcentaje:  11.8 %
# total de 10
# porcentaje:  6.4 %
# total de 11
# porcentaje:  5.2 %
# total de 12
# porcentaje:  3.8 %

# %% [markdown]
# ### con 100000  interacciones

# %%
import random
uno=0
dos=0
tres=0
cuatro=0
cinco=0
seis=0
siete=0
ocho=0
nueve=0
dies=0
once=0
doce=0
for i in range(10000):
   numero1=(random.randint(1, 6))
  # numero1 =(randrange(6))
  # print (numero1)
   numero3=(random.randint(1, 6))
   #numero3 = (randrange(6))
  # numero=(choice(["uno", "dos", "tres", "cuatro","cinco", "seis"]))
   #numero2=(choice(["uno", "dos", "tres", "cuatro","cinco", "seis"]))
   total= numero1 +numero3
   if total == 2:
    dos=dos+1  
   if total == 3:
    tres=tres+1
   if total == 4:
    cuatro=cuatro+1
   if total == 5:
    cinco=cinco+1
   if total == 6:
    seis=seis+1
   if total == 7:
    siete=siete+1
   if total == 8:
    ocho=ocho+1 
   if total == 9:
    nueve=nueve+1
   if total == 10:
    dies=dies+1
   if total == 11:
    once=once+1
   if total == 12:
    doce=doce+1
  
    
print("total de 2")
print("porcentaje: ", round((dos/10000)*100,2),"%")
print("total de 3")
print("porcentaje: ", round((tres/10000)*100,2),"%")
print("total de 4")
print("porcentaje: ", round((cuatro/10000)*100,2),"%")
print("total de 5")
print("porcentaje: ", round((cinco/10000)*100,2),"%")
print("total de 6")
print("porcentaje: ", round((seis/10000)*100,2),"%")
print("total de 7")
print("porcentaje: ", round((siete/10000)*100,2),"%")
print("total de 8")
print("porcentaje: ", round((ocho/10000)*100,2),"%")
print("total de 9")
print("porcentaje: ", round((nueve/10000)*100,2),"%")
print("total de 10")
print("porcentaje: ", round((dies/10000)*100,2),"%")
print("total de 11")
print("porcentaje: ", round((once/10000)*100,2),"%")
print("total de 12")
print("porcentaje: ", round((doce/10000)*100,2),"%")
# Out:
# total de 2
# porcentaje:  3.01 %
# total de 3
# porcentaje:  5.43 %
# total de 4
# porcentaje:  8.35 %
# total de 5
# porcentaje:  11.2 %
# total de 6
# porcentaje:  13.76 %
# total de 7
# porcentaje:  16.95 %
# total de 8
# porcentaje:  13.8 %
# total de 9
# porcentaje:  11.0 %
# total de 10
# porcentaje:  7.92 %
# total de 11
# porcentaje:  5.81 %
# total de 12
# porcentaje:  2.77 %

# %% [markdown]
# conculcion  mediante las pruebas realizadas podemos determinar que los numeros que mas se repiten son 5, 6, 7 y 8.
